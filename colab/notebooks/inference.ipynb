# %%
# !git clone https://github.com/hawlermathew2007/TellMom.git
# Out:
# Cloning into 'TellMom'...
# remote: Enumerating objects: 636, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 636 (delta 100), reused 95 (delta 78), pack-reused 482 (from 1)
# Receiving objects: 100% (636/636), 7.54 MiB | 27.66 MiB/s, done.
# Resolving deltas: 100% (320/320), done.

# %%
# %cd TellMom
# Out:
# /content/TellMom

# %%
# !git checkout fullstack-app
# Out:
# Branch 'fullstack-app' set up to track remote branch 'fullstack-app' from 'origin'.
# Switched to a new branch 'fullstack-app'

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Total 7 (delta 6), reused 7 (delta 6), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 529 bytes | 264.00 KiB/s, done.
# From https://github.com/hawlermathew2007/TellMom
#    58c3c34..a2cc18d  fullstack-app -> origin/fullstack-app
# Updating 58c3c34..a2cc18d
# Fast-forward
#  backend/routers/ingest.py | 2 +-
#  colab/server.py           | 3 +--
#  2 files changed, 2 insertions(+), 3 deletions(-)

# %%
# %cd colab
# Out:
# [Errno 2] No such file or directory: 'colab'
# /content/TellMom/colab

# %%
import os

os.environ["BACKEND_BASE_URL"] = "http://45.151.155.170:8000"
os.environ["BACKEND_WS_URL"] = "ws://45.151.155.170:8000/stream"
os.environ["BACKEND_PASSWORD"] = "1234"

# %%
# !python server.py
# Out:
# 2026-07-01T13:58:17  INFO      grooming.pipeline — Device: cuda
# 2026-07-01T13:58:17  INFO      grooming.pipeline — ============================================================
# 2026-07-01T13:58:17  INFO      grooming.pipeline — Server check-in
# 2026-07-01T13:58:17  INFO      grooming.pipeline — ============================================================
# 2026-07-01T13:58:17  INFO      grooming.pipeline — [check-in] Attempt 1/3 → POST http://45.151.155.170:8000/checkin
# 2026-07-01T13:58:18  INFO      grooming.pipeline — [check-in] SUCCESS  HTTP 200  server_info={'status': 'ok', 'message': 'Classifier registered', 'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6ImNsYXNzaWZpZXI6c3RyZWFtIiwiaWF0IjoxNzgyOTE0Mjk4LCJleHAiOjE3ODI5Mjg2OTh9.2m07kzLZRlZai-Dk4Ov0LVJc8-HHFozC58pOZOOt7yI'}
# ...
